# %%
from deltaengine.Forecast import Forecast

# %%
ideal = Forecast(days=3000, scene="ideal")
reality = Forecast(days=3000, scene="data")

# %%
reality.data.plot(y="balance", x="date")
ideal.data.plot(y="balance", x="date")

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

plotly.tools.set_credentials_file(username='sansburyjacob', api_key='aRJN1U0jX9f7px1HKdd2')

# %%
# plot the forecast on a plotly line chart
data = [go.Scatter(x=reality.date, y=reality.balance), go.Scatter(x=ideal.date, y=ideal.balance)]
py.iplot(data, filename='forecast-1-year')
